# %% [markdown]
# <a href="https://colab.research.google.com/github/INVISIBLE-SAM/PROJECT/blob/main/Xception_adni.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES
# TO THE CORRECT LOCATION (/kaggle/input) IN YOUR NOTEBOOK,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.

import os
import sys
from tempfile import NamedTemporaryFile
from urllib.request import urlopen
from urllib.parse import unquote, urlparse
from urllib.error import HTTPError
from zipfile import ZipFile
import tarfile
import shutil

CHUNK_SIZE = 40960
DATA_SOURCE_MAPPING = 'adni-dataset-train-test-split:https%3A%2F%2Fstorage.googleapis.com%2Fkaggle-data-sets%2F5802560%2F9528540%2Fbundle%2Farchive.zip%3FX-Goog-Algorithm%3DGOOG4-RSA-SHA256%26X-Goog-Credential%3Dgcp-kaggle-com%2540kaggle-161607.iam.gserviceaccount.com%252F20241002%252Fauto%252Fstorage%252Fgoog4_request%26X-Goog-Date%3D20241002T051627Z%26X-Goog-Expires%3D259200%26X-Goog-SignedHeaders%3Dhost%26X-Goog-Signature%...'

KAGGLE_INPUT_PATH='/kaggle/input'
KAGGLE_WORKING_PATH='/kaggle/working'
KAGGLE_SYMLINK='kaggle'

# !umount /kaggle/input/ 2> /dev/null
shutil.rmtree('/kaggle/input', ignore_errors=True)
os.makedirs(KAGGLE_INPUT_PATH, 0o777, exist_ok=True)
os.makedirs(KAGGLE_WORKING_PATH, 0o777, exist_ok=True)

try:
  os.symlink(KAGGLE_INPUT_PATH, os.path.join("..", 'input'), target_is_directory=True)
except FileExistsError:
  pass
try:
  os.symlink(KAGGLE_WORKING_PATH, os.path.join("..", 'working'), target_is_directory=True)
except FileExistsError:
  pass

for data_source_mapping in DATA_SOURCE_MAPPING.split(','):
    directory, download_url_encoded = data_source_mapping.split(':')
    download_url = unquote(download_url_encoded)
    filename = urlparse(download_url).path
    destination_path = os.path.join(KAGGLE_INPUT_PATH, directory)
    try:
        with urlopen(download_url) as fileres, NamedTemporaryFile() as tfile:
            total_length = fileres.headers['content-length']
            print(f'Downloading {directory}, {total_length} bytes compressed')
            dl = 0
            data = fileres.read(CHUNK_SIZE)
            while len(data) > 0:
                dl += len(data)
                tfile.write(data)
                done = int(50 * dl / int(total_length))
                sys.stdout.write(f"\r[{'=' * done}{' ' * (50-done)}] {dl} bytes downloaded")
                sys.stdout.flush()
                data = fileres.read(CHUNK_SIZE)
            if filename.endswith('.zip'):
              with ZipFile(tfile) as zfile:
                zfile.extractall(destination_path)
            else:
              with tarfile.open(tfile.name) as tarfile:
                tarfile.extractall(destination_path)
            print(f'\nDownloaded and uncompressed: {directory}')
    except HTTPError as e:
        print(f'Failed to load (likely expired) {download_url} to path {destination_path}')
        continue
    except OSError as e:
        print(f'Failed to load {download_url} to path {destination_path}')
        continue

print('Data source import complete.')
# Out:
# Downloading adni-dataset-train-test-split, 76512619 bytes compressed
# [==================================================] 76512619 bytes downloaded
# Downloaded and uncompressed: adni-dataset-train-test-split
# Data source import complete.

# %%
from tensorflow.keras.applications import Xception

from tensorflow.keras.layers import Input, Lambda, Dense, Flatten
from tensorflow.keras.models import Model
import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
import numpy as np

from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score, roc_curve

# %%
vgg=keras.applications.Xception(input_shape=[224,224,3],weights='imagenet',include_top=False)
for layer in vgg.layers:
    layer.trainable=False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
x=Flatten()(vgg.output)
prediction=Dense(3,activation='softmax')(x)
model=Model(inputs=vgg.input,outputs=prediction)

# %%
from tensorflow.keras.optimizers import Adam

# Set the desired learning rate
learning_rate = 1e-5

# Create the Adam optimizer with the specified learning rate
optimizer = Adam(learning_rate=learning_rate)
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
train_datagen = ImageDataGenerator(rescale=1.0/255,
                                   shear_range=0.2,
                                   zoom_range=0.2,
                                   horizontal_flip=True,
                                  rotation_range=40,
                                  )
test_datagen = ImageDataGenerator(rescale=1.0/255,)
pred_datagen =ImageDataGenerator(rescale=1.0/255)

# Loading the training and test sets
training_set = train_datagen.flow_from_directory('/kaggle/input/adni-dataset-train-test-split/Adni 1/Train',
                                                 target_size=(224, 224),
                                                 batch_size=32,
                                                 class_mode='categorical')
test_set = test_datagen.flow_from_directory('/kaggle/input/adni-dataset-train-test-split/Adni 1/Valid',
                                            target_size=(224, 224),
                                            batch_size=32,
                                            shuffle=False,
                                            class_mode='categorical')
pred_set=pred_datagen.flow_from_directory('/kaggle/input/adni-dataset-train-test-split/Adni 1/Test',
                                            target_size=(224, 224),
                                            batch_size=32,
                                            shuffle=False,
                                            class_mode='categorical')

# Adjusting the steps per epoch and validation steps
steps_per_epoch = training_set.samples // training_set.batch_size
validation_steps =test_set.samples // test_set.batch_size
# Out:
# Found 2604 images belonging to 3 classes.
# Found 558 images belonging to 3 classes.
# Found 562 images belonging to 3 classes.

# %%
history = model.fit(training_set,  # Repeat the dataset
                    validation_data=test_set,  # Repeat the dataset
                    epochs=70,
                    steps_per_epoch=steps_per_epoch,
                    validation_steps=validation_steps)
# Out:
# Epoch 1/70
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 69s 609ms/step - accuracy: 0.4211 - loss: 5.8861 - val_accuracy: 0.6195 - val_loss: 1.2189
# Epoch 2/70
#  1/81 ━━━━━━━━━━━━━━━━━━━━ 8s 108ms/step - accuracy: 0.5938 - loss: 1.0145
# /usr/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 5s 65ms/step - accuracy: 0.5938 - loss: 1.0145 - val_accuracy: 0.7143 - val_loss: 0.4976
# Epoch 3/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 47s 394ms/step - accuracy: 0.6540 - loss: 1.1050 - val_accuracy: 0.6562 - val_loss: 1.2859
# Epoch 4/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 873us/step - accuracy: 0.6875 - loss: 1.5292 - val_accuracy: 0.6429 - val_loss: 0.7573
# Epoch 5/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 40s 393ms/step - accuracy: 0.6432 - loss: 1.4218 - val_accuracy: 0.5662 - val_loss: 2.1472
# Epoch 6/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step - accuracy: 0.4375 - loss: 2.0739 - val_accuracy: 0.4286 - val_loss: 0.9850
# Epoch 7/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 41s 394ms/step - accuracy: 0.6671 - loss: 1.2773 - val_accuracy: 0.7721 - val_loss: 0.7407
# Epoch 8/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 841us/step - accuracy: 0.8125 - loss: 0.5118 - val_accuracy: 1.0000 - val_loss: 0.0059
# Epoch 9/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 34s 391ms/step - accuracy: 0.7117 - loss: 1.0104 - val_accuracy: 0.7188 - val_loss: 0.9819
# Epoch 10/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 867us/step - accuracy: 0.6562 - loss: 1.1986 - val_accuracy: 0.2857 - val_loss: 3.9790
# Epoch 11/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 34s 385ms/step - accuracy: 0.6780 - loss: 1.2916 - val_accuracy: 0.7463 - val_loss: 0.9889
# Epoch 12/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 840us/step - accuracy: 0.8438 - loss: 0.3752 - val_accuracy: 1.0000 - val_loss: 5.8987e-05
# Epoch 13/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 40s 387ms/step - accuracy: 0.6882 - loss: 1.4044 - val_accuracy: 0.7739 - val_loss: 0.7348
# Epoch 14/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 795us/step - accuracy: 0.8125 - loss: 0.5413 - val_accuracy: 0.9286 - val_loss: 0.0936
# Epoch 15/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 41s 389ms/step - accuracy: 0.7796 - loss: 0.7225 - val_accuracy: 0.7868 - val_loss: 0.6988
# Epoch 16/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 856us/step - accuracy: 0.7188 - loss: 1.2053 - val_accuracy: 1.0000 - val_loss: 0.0085
# Epoch 17/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 33s 382ms/step - accuracy: 0.7894 - loss: 0.7532 - val_accuracy: 0.7812 - val_loss: 0.8027
# Epoch 18/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 804us/step - accuracy: 0.7500 - loss: 1.0773 - val_accuracy: 0.5000 - val_loss: 2.0796
# Epoch 19/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 41s 387ms/step - accuracy: 0.7655 - loss: 0.9953 - val_accuracy: 0.7353 - val_loss: 1.2627
# Epoch 20/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7188 - loss: 1.3561 - val_accuracy: 0.5714 - val_loss: 1.0593
# Epoch 21/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 34s 386ms/step - accuracy: 0.7854 - loss: 0.8003 - val_accuracy: 0.8640 - val_loss: 0.4810
# Epoch 22/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step - accuracy: 0.8750 - loss: 0.2638 - val_accuracy: 0.7857 - val_loss: 0.6001
# Epoch 23/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 41s 385ms/step - accuracy: 0.8082 - loss: 0.6811 - val_accuracy: 0.7371 - val_loss: 0.9221
# Epoch 24/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8750 - loss: 0.2741 - val_accuracy: 1.0000 - val_loss: 6.6708e-04
# Epoch 25/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 42s 405ms/step - accuracy: 0.8181 - loss: 0.5753 - val_accuracy: 0.8290 - val_loss: 0.5550
# Epoch 26/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 787us/step - accuracy: 0.9062 - loss: 0.3277 - val_accuracy: 1.0000 - val_loss: 0.0074
# Epoch 27/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 34s 387ms/step - accuracy: 0.8675 - loss: 0.4023 - val_accuracy: 0.8842 - val_loss: 0.3104
# Epoch 28/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8438 - loss: 0.6430 - val_accuracy: 1.0000 - val_loss: 0.0301
# Epoch 29/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 34s 389ms/step - accuracy: 0.8231 - loss: 0.6091 - val_accuracy: 0.8585 - val_loss: 0.4617
# Epoch 30/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 855us/step - accuracy: 0.9062 - loss: 0.2018 - val_accuracy: 0.9286 - val_loss: 0.3912
# Epoch 31/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 41s 389ms/step - accuracy: 0.8462 - loss: 0.4860 - val_accuracy: 0.7812 - val_loss: 0.7934
# Epoch 32/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8125 - loss: 0.9349 - val_accuracy: 0.9286 - val_loss: 0.1640
# Epoch 33/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 42s 406ms/step - accuracy: 0.7705 - loss: 0.9876 - val_accuracy: 0.7831 - val_loss: 0.8579
# Epoch 34/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 823us/step - accuracy: 0.8750 - loss: 0.4460 - val_accuracy: 1.0000 - val_loss: 3.5374e-04
# Epoch 35/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 34s 388ms/step - accuracy: 0.7990 - loss: 0.9343 - val_accuracy: 0.7739 - val_loss: 0.9833
# Epoch 36/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7188 - loss: 1.0053 - val_accuracy: 1.0000 - val_loss: 2.3280e-04
# Epoch 37/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 34s 390ms/step - accuracy: 0.8327 - loss: 0.7118 - val_accuracy: 0.8033 - val_loss: 0.7526
# Epoch 38/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 844us/step - accuracy: 0.7500 - loss: 1.1721 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 39/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 35s 393ms/step - accuracy: 0.8079 - loss: 0.8727 - val_accuracy: 0.8768 - val_loss: 0.4217
# Epoch 40/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 845us/step - accuracy: 0.8125 - loss: 0.6595 - val_accuracy: 0.7857 - val_loss: 0.6605
# Epoch 41/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 35s 399ms/step - accuracy: 0.8509 - loss: 0.5426 - val_accuracy: 0.7096 - val_loss: 1.5629
# Epoch 42/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 830us/step - accuracy: 0.7188 - loss: 1.8943 - val_accuracy: 1.0000 - val_loss: 4.1600e-04
# Epoch 43/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 41s 396ms/step - accuracy: 0.8207 - loss: 0.7030 - val_accuracy: 0.8070 - val_loss: 0.8230
# Epoch 44/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step - accuracy: 0.7500 - loss: 1.3803 - val_accuracy: 0.9286 - val_loss: 0.0856
# Epoch 45/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 40s 387ms/step - accuracy: 0.8273 - loss: 0.8626 - val_accuracy: 0.8676 - val_loss: 0.4324
# Epoch 46/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 816us/step - accuracy: 0.8438 - loss: 0.8091 - val_accuracy: 1.0000 - val_loss: 0.0053
# Epoch 47/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 41s 389ms/step - accuracy: 0.8138 - loss: 0.7850 - val_accuracy: 0.7776 - val_loss: 1.3484
# Epoch 48/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 910us/step - accuracy: 0.7812 - loss: 0.8247 - val_accuracy: 1.0000 - val_loss: 4.2575e-07
# Epoch 49/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 42s 406ms/step - accuracy: 0.7769 - loss: 1.0377 - val_accuracy: 0.8162 - val_loss: 0.8193
# Epoch 50/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step - accuracy: 0.9062 - loss: 0.3230 - val_accuracy: 1.0000 - val_loss: 3.5867e-04
# Epoch 51/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 40s 388ms/step - accuracy: 0.8949 - loss: 0.3682 - val_accuracy: 0.6985 - val_loss: 1.7318
# Epoch 52/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 858us/step - accuracy: 0.7188 - loss: 1.6302 - val_accuracy: 1.0000 - val_loss: 3.3579e-05
# Epoch 53/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 34s 394ms/step - accuracy: 0.8697 - loss: 0.5129 - val_accuracy: 0.8566 - val_loss: 0.6145
# Epoch 54/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 863us/step - accuracy: 0.9375 - loss: 0.0996 - val_accuracy: 1.0000 - val_loss: 0.0232
# Epoch 55/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 34s 390ms/step - accuracy: 0.8491 - loss: 0.6422 - val_accuracy: 0.8621 - val_loss: 0.5923
# Epoch 56/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step - accuracy: 0.8750 - loss: 0.6888 - val_accuracy: 1.0000 - val_loss: 0.0428
# Epoch 57/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 35s 389ms/step - accuracy: 0.8564 - loss: 0.5897 - val_accuracy: 0.8676 - val_loss: 0.4890
# Epoch 58/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 859us/step - accuracy: 0.9375 - loss: 0.2086 - val_accuracy: 1.0000 - val_loss: 6.8065e-05
# Epoch 59/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 39s 386ms/step - accuracy: 0.8741 - loss: 0.4437 - val_accuracy: 0.8254 - val_loss: 0.6875
# Epoch 60/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 849us/step - accuracy: 0.8438 - loss: 1.1024 - val_accuracy: 1.0000 - val_loss: 1.6579e-04
# Epoch 61/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 41s 389ms/step - accuracy: 0.8506 - loss: 0.5725 - val_accuracy: 0.8787 - val_loss: 0.5168
# Epoch 62/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8750 - loss: 0.3840 - val_accuracy: 1.0000 - val_loss: 0.0319
# Epoch 63/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 34s 387ms/step - accuracy: 0.8836 - loss: 0.4809 - val_accuracy: 0.8658 - val_loss: 0.5105
# Epoch 64/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8750 - loss: 0.5015 - val_accuracy: 0.9286 - val_loss: 0.2132
# Epoch 65/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 41s 391ms/step - accuracy: 0.8869 - loss: 0.5162 - val_accuracy: 0.8750 - val_loss: 0.5734
# Epoch 66/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7812 - loss: 0.8107 - val_accuracy: 0.8571 - val_loss: 0.2031
# Epoch 67/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 41s 400ms/step - accuracy: 0.8531 - loss: 0.6240 - val_accuracy: 0.8915 - val_loss: 0.4790
# Epoch 68/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 843us/step - accuracy: 0.8750 - loss: 0.5179 - val_accuracy: 1.0000 - val_loss: 1.1367e-04
# Epoch 69/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 34s 393ms/step - accuracy: 0.8641 - loss: 0.5525 - val_accuracy: 0.7868 - val_loss: 0.9772
# Epoch 70/70
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 947us/step - accuracy: 0.8750 - loss: 0.3752 - val_accuracy: 1.0000 - val_loss: 0.0050

# %%
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.show()
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='upper right')
plt.show()

# %%
from sklearn.metrics import classification_report
import numpy as np

# Assuming y_true are the true labels and y_pred are the predicted probabilities
y_true = pred_set.classes  # True labels from the dataset
y_pred = model.predict(pred_set)  # Predicted probabilities from the model
y_pred_classes = np.argmax(y_pred, axis=1)  # Convert predicted probabilities to class labels

# Update the target class names
target_names = ['Alzheimer\'s Disease (AD)', 'Cognitive Impairment (CI)', 'Cognitively Normal (CN)']  # Update for 3 classes

# Generate the classification report
report = classification_report(y_true, y_pred_classes, target_names=target_names)

print(report)
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 11s 513ms/step
#                            precision    recall  f1-score   support
#
#  Alzheimer's Disease (AD)       0.95      0.72      0.82       170
# Cognitive Impairment (CI)       0.84      0.89      0.86       196
#   Cognitively Normal (CN)       0.82      0.93      0.87       196
#
#                  accuracy                           0.85       562
#                 macro avg       0.87      0.85      0.85       562
#              weighted avg       0.86      0.85      0.85       562

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set Seaborn style and context for improved aesthetics
sns.set(style="whitegrid", context="talk")  # White grid background and larger font sizes

# Increase the scale and reduce plot size using Seaborn
plt.figure(figsize=(10, 6), dpi=100)  # Adjust figure size and resolution
sns.lineplot(x=range(len(history.history['loss'])), y=history.history['loss'], label='Training Loss')
sns.lineplot(x=range(len(history.history['val_loss'])), y=history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss', fontsize=16)  # Increase font size of title
plt.xlabel('Epoch', fontsize=14)  # Increase font size of x-axis
plt.ylabel('Loss', fontsize=14)  # Increase font size of y-axis
plt.legend(loc='upper right', fontsize=12)  # Adjust legend font size
plt.grid(True)  # Add grid lines
plt.tight_layout()  # Adjust padding
plt.show()

# Plot accuracy using Seaborn
plt.figure(figsize=(10, 6), dpi=100)  # Adjust figure size and resolution
sns.lineplot(x=range(len(history.history['accuracy'])), y=history.history['accuracy'], label='Training Accuracy')
sns.lineplot(x=range(len(history.history['val_accuracy'])), y=history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy', fontsize=16)  # Increase font size of title
plt.xlabel('Epoch', fontsize=14)  # Increase font size of x-axis
plt.ylabel('Accuracy', fontsize=14)  # Increase font size of y-axis
plt.legend(loc='upper right', fontsize=12)  # Adjust legend font size
plt.grid(True)  # Add grid lines
plt.tight_layout()  # Adjust padding
plt.show()

# %%
import numpy as np
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'model' is your trained model
# Predicting the probabilities for the pred_set
y_pred = model.predict(pred_set)  # y_pred shape will be (num_samples, 3) for 3 classes
y_true = pred_set.classes  # The true labels from the data
y_true = np.eye(3)[y_true]  # One-hot encoding for true classes (3 classes)

# Define class names
class_names = ['Alzheimer\'s Disease (AD)', 'Cognitive Impairment (CI)', 'Cognitively Normal (CN)']

# Compute ROC curve and ROC area for each class
fpr = {}
tpr = {}
roc_auc = {}

for i in range(3):  # Adjusted for 3 classes
    fpr[i], tpr[i], _ = roc_curve(y_true[:, i], y_pred[:, i])
    roc_auc[i] = roc_auc_score(y_true[:, i], y_pred[:, i])

# Use Seaborn styling
sns.set(style="whitegrid", context="talk")

# Plot ROC curves
plt.figure(figsize=(10, 7), dpi=100)  # Normal size and resolution
colors = ['blue', 'red', 'green']  # 3 colors for 3 classes

for i, color in zip(range(3), colors):  # Adjusted for 3 classes
    plt.plot(fpr[i], tpr[i], color=color, lw=2,
             label='{0} (AUC = {1:0.2f})'.format(class_names[i], roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=14)
plt.ylabel('True Positive Rate', fontsize=14)
plt.title('Receiver Operating Characteristic (ROC) Curve', fontsize=16)
plt.legend(loc="lower right", fontsize=12)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# Assuming 'model' is your trained model
# Predicting the classes for the pred_set
predictions = model.predict(pred_set)
predicted_classes = np.argmax(predictions, axis=1)

# Getting the true classes from the pred_set
true_classes = pred_set.classes

# Creating the confusion matrix
cm = confusion_matrix(true_classes, predicted_classes)

# Adjust figure size to avoid overlap
plt.figure(figsize=(10, 8))

# Displaying the confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=pred_set.class_indices.keys())
disp.plot(cmap=plt.cm.Blues, xticks_rotation=45)  # Rotate x-axis labels

# Remove the grid from the plot
plt.grid(False)  # Turns off the grid

# Adjust layout to prevent text overlap
plt.tight_layout()

plt.show()
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 109ms/step

# %%
import numpy as np
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'model' is your trained model
# Predicting the probabilities for the pred_set
y_pred = model.predict(pred_set)  # y_pred shape will be (num_samples, 3) for 3 classes
y_true = pred_set.classes  # The true labels from the data
y_true = np.eye(3)[y_true]  # One-hot encoding for true classes (3 classes)

# Define class names
class_names = ['Alzheimer\'s Disease (AD)', 'Cognitive Impairment (CI)', 'Cognitively Normal (CN)']

# Compute ROC curve and ROC area for each class
fpr = {}
tpr = {}
roc_auc = {}

for i in range(3):  # Adjusted for 3 classes
    fpr[i], tpr[i], _ = roc_curve(y_true[:, i], y_pred[:, i])
    roc_auc[i] = roc_auc_score(y_true[:, i], y_pred[:, i])

# Use Seaborn styling
sns.set(style="whitegrid", context="talk")

# Plot ROC curves
plt.figure(figsize=(10, 7), dpi=100)  # Normal size and resolution
colors = ['blue', 'red', 'green']  # 3 colors for 3 classes

for i, color in zip(range(3), colors):  # Adjusted for 3 classes
    plt.plot(fpr[i], tpr[i], color=color, lw=2,
             label='{0} (AUC = {1:0.2f})'.format(class_names[i], roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=14)
plt.ylabel('True Positive Rate', fontsize=14)
plt.title('Receiver Operating Characteristic (ROC) Curve', fontsize=16)
plt.legend(loc="lower right", fontsize=12)
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 115ms/step
